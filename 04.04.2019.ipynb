# %% [markdown]
# # Changing the script

# %% [markdown]
# The file, Results_filtered_gdp_FINAL contains chromosome on column 1 and base position on 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write another function that gets the snp effects from ebi.
# Execute this function in the function getgdp()

# %% [markdown]
# The code snippet obtain_ensembl.py works and obtains the snp effects from threshfile.
